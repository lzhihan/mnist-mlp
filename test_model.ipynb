# %%
import torch

# %%
mlp_dict = torch.load('best_mlp_mnist.pth')
mlp_dict
# Out:
# OrderedDict([('fc1.weight',
#               tensor([[ 1.6623e-02,  3.3575e-02, -3.3891e-02,  ...,  2.3730e-06,
#                        -1.9156e-02,  1.0176e-02],
#                       [-1.7421e-02, -1.4566e-02,  2.5780e-02,  ...,  2.0299e-02,
#                         1.2481e-02,  1.8252e-02],
#                       [-3.1046e-03,  6.5138e-03, -6.0915e-03,  ...,  1.3673e-02,
#                        -1.4405e-02, -1.0638e-02],
#                       ...,
#                       [-2.4021e-02,  3.0915e-02,  1.2502e-02,  ...,  1.7670e-02,
#                         4.3555e-03,  2.9113e-02],
#                       [ 4.5385e-03,  3.3058e-02,  2.5392e-02,  ...,  3.4488e-02,
#                         1.9551e-03, -1.6471e-02],
#                       [ 2.1052e-02, -7.2552e-03,  3.1457e-02,  ...,  3.9914e-03,
#                         2.2742e-02,  1.2525e-02]], device='cuda:0')),
#              ('fc1.bias',
# ...

# %%
from train_mlp import MLP
mlp = MLP()
mlp.load_state_dict(mlp_dict)
mlp
# Out:
# MLP(
#   (fc1): Linear(in_features=784, out_features=256, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=256, out_features=10, bias=True)
# )
